# %%
import os, torchvision
import numpy as np
import torch
import torch.nn as nn
import argparse
import csv
import json

import torch.backends.cudnn as cudnn
import torch.nn.parallel
import torch.utils.data
import torchvision.models as models
from PIL import Image
from torch.nn import functional as F
import torchvision.datasets as datasets
import torchvision.transforms as transforms

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
from model import get_model
from utils_metrics import *
from utils import get_dataset
from predictions import has_tomatoes

# %% [markdown]
# # Show an exemple of image without any preprocessing

# %%
def show_img(name, extent=(5, 5)):  
    img = Image.open(name).convert("RGB")
    img = img.resize((224, 224), Image.BILINEAR)
    print("size: ", img.size)
    
    img = mpimg.imread(name)
    plt.figure(figsize=extent)
    plt.axis('off')
    imgplot = plt.imshow(img)
    plt.show()
    
    '''
    plt.figure(figsize=extent)
    plt.axis('off')
    plt.imshow(img)
    plt.show()
    '''

# %%
img_name = "3a0edd8900f5ccf2fc0c38b1e99dce73.jpeg"
json_file = "images/img_annotations.json"
csv_file =  "images/label_mapping.csv"

# %%
show_img("./assignment_imgs/" + img_name)
# Out:
# size:  (224, 224)

# %% [markdown]
# # plot loss/ accuracy

# %% [markdown]
# the graphs of losses and accuracies are updated and saved at each iteration. Below I plot the graphs up to iteration 1000

# %%
show_img('images/accuracy.png', extent=(10, 10))
# Out:
# size:  (224, 224)

# %%
show_img('images/loss.png', extent=(10, 10))
# Out:
# size:  (224, 224)

# %% [markdown]
# # Test phase

# %%
# Wrong path 
test_img_path1 = "/home/nora/Téléchargements/test_foodvisor/Assignment2/23282_2017_02_03_16_19_18.jpg"

# %%
has_tomatoes(test_img_path1)
# Out:
# Error! file cannot be openned

# %%
# correct path
test_img_path2 = "/home/nora/Téléchargements/test_foodvisor/Assignment2/assignment_imgs/3a0edd8900f5ccf2fc0c38b1e99dce73.jpeg"

# %%
has_tomatoes(test_img_path2)
# Out:
# True
