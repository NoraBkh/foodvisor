# %%
import os, torchvision
import numpy as np
import torch
import torch.nn as nn
import argparse
import csv
import json

import torch.backends.cudnn as cudnn
import torch.nn.parallel
import torch.utils.data
import torchvision.models as models
from PIL import Image
from torch.nn import functional as F
import torchvision.datasets as datasets
import torchvision.transforms as transforms

import matplotlib.pyplot as plt

# %%
from model import get_model
from utils_metrics import *
from utils import get_dataset
from predictions import has_tomatoes

# %% [markdown]
# # Show an exemple of image without any preprocessing

# %%
def show_img(name, extent=[-10,10,-10,10]):  
    img = Image.open(name).convert("RGB")
    img = img.resize((224, 224), Image.BILINEAR)
    print("size: ", img.size)
    plt.imshow(img, extent=extent)
    plt.show()

# %%
img_name = "3a0edd8900f5ccf2fc0c38b1e99dce73.jpeg"
json_file = "images/img_annotations.json"
csv_file =  "images/label_mapping.csv"

# %%
show_img("./assignment_imgs/" + img_name)
# Out:
# size:  (224, 224)

# %% [markdown]
# # plot loss/ accuracy

# %% [markdown]
# the graphs of losses and accuracies are updated and saved at each iteration. Below I plot the graphs up to iteration 1000

# %%
show_img('images/accuracy.png', extent=[10,50,0,50])
# Out:
# size:  (224, 224)

# %%
show_img('images/loss.png')
# Out:
# size:  (224, 224)

# %% [markdown]
# # Test phase

# %%
test_img_path = "/home/nora/Téléchargements/test_foodvisor/Assignment2/assignment_imgs/23282_2017_02_03_16_19_18.jpg"

# %%
has_tomatoes(test_img_path)
# Out:
# False
